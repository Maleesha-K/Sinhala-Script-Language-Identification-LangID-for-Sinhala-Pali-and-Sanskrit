# %%
input_dir = 'datasets/raw_download/commonlid'
output_file = 'datasets/preprocessed/commonlid.jsonl'

# %%
import os
# Auto-resolve the project root if running manually
if not os.path.exists("Makefile") and os.path.exists("../../Makefile"):
    os.chdir("../../")

import os
import json

print(f"Preprocessing data from {input_dir}...")
raw_file_path = os.path.join(input_dir, "raw_data.jsonl")

if not os.path.exists(raw_file_path):
    print(f"Error: {raw_file_path} not found.")
else:
    os.makedirs(os.path.dirname(output_file), exist_ok=True)
    processed_count = 0
    with open(raw_file_path, "r", encoding="utf-8") as f_in, \
         open(output_file, "w", encoding="utf-8") as f_out:
         
        for line in f_in:
            row = json.loads(line)
            
            # The CommonLID dataset has columns: text, tag, line_id, updated
            standard_record = {
                "text": row["text"],
                "label": row["tag"], # Using the tag as the label
                "source": "commonlid"
            }
            f_out.write(json.dumps(standard_record, ensure_ascii=False) + "\n")
            processed_count += 1
            
    print(f"Successfully processed {processed_count} records to {output_file}")
# Out:
# Preprocessing data from datasets/raw_download/commonlid...
# Successfully processed 373230 records to datasets/preprocessed/commonlid.jsonl
