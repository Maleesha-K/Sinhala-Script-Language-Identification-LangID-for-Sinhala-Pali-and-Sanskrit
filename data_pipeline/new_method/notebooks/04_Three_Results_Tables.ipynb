# %% [markdown]
# # 04 — Export the three results tables
# Run notebooks 01–03 first. This creates one table per condition. Each row identifies a model and benchmark; the columns contain per-language F1 and macro averages. CommonLID, FLORES+, and WiLI-2018 remain separate.

# %%
from pathlib import Path
import os, sys
candidates = [Path.cwd(), Path.cwd().parent, Path('/content/lid_finetuning_bundle')]
ROOT = next((p for p in candidates if (p/'config.json').exists() and (p/'lidlab').exists()), None)
if ROOT is None:
    raise FileNotFoundError('Extract the complete ZIP first and set ROOT to its lid_finetuning_bundle folder.')
os.chdir(ROOT)
if str(ROOT) not in sys.path: sys.path.insert(0, str(ROOT))
print('Project folder:', ROOT)
# Out:
# Project folder: d:\Projects\ML Projects\LangID - DSE project\data_pipeline\new_method

# %%
from lidlab.data import load_config
from lidlab.metrics import make_tables
c = load_config()
tables = make_tables(c)
for phase, table in tables.items():
    print(phase)
    display(table.round(4))
print('Saved CSV and LaTeX tables to:', ROOT/c['output_dir']/'tables')
# Out:
# zero_shot
#                        Sinhala (Sinhala)  Pali (Sinhala)  Sanskrit (Sinhala)  \
# nllb — commonlid                  0.5442             0.0                 0.0
# nllb — flores_plus                0.5442             0.0                 0.0
# nllb — wili_2018                  0.5442             0.0                 0.0
# glotlid — commonlid               0.5451             0.0                 0.0
# glotlid — flores_plus             0.5451             0.0                 0.0
# glotlid — wili_2018               0.5451             0.0                 0.0
# conlid — commonlid                0.5509             0.0                 0.0
# conlid — flores_plus              0.5509             0.0                 0.0
# conlid — wili_2018                0.5509             0.0                 0.0
#
#                        Sanskrit (Devanagari)  English   Tamil   Hindi  \
# nllb — commonlid                      0.9314   0.9234  0.9747  0.9641
# nllb — flores_plus                    0.9890   0.9840  1.0000  0.9907
# nllb — wili_2018                      0.9969   0.9305  0.9939  0.9894
# glotlid — commonlid                   0.9667   0.9252  0.9878  0.9713
# glotlid — flores_plus                 0.9945   1.0000  1.0000  0.9921
# glotlid — wili_2018                   0.9975   0.9381  0.9949  0.9184
# conlid — commonlid                    0.9624   0.8501  0.9818  0.9447
# conlid — flores_plus                  0.9985   0.9960  0.9995  0.9970
# conlid — wili_2018                    0.9985   0.9443  0.9944  0.9904
#
#                        Bengali  Modern Standard Arabic  French  German  \
# nllb — commonlid        0.9866                  0.9931  0.9288  0.9410
# nllb — flores_plus      1.0000                  0.6664  0.9995  0.9995
# nllb — wili_2018        0.9429                  0.9975  0.9899  0.9899
# glotlid — commonlid     0.9789                  0.9505  0.9250  0.9217
# glotlid — flores_plus   0.9995                  0.6054  1.0000  1.0000
# glotlid — wili_2018     0.9451                  0.9541  0.9869  0.9754
# conlid — commonlid      0.9623                  0.7224  0.8973  0.8955
# conlid — flores_plus    1.0000                  0.3740  1.0000  0.9970
# conlid — wili_2018      0.9435                  0.6724  0.9808  0.9707
#
#                        Macro F1 (target 3)  Macro F1 (replay 8)  \
# nllb — commonlid                    0.1814               0.9554
# nllb — flores_plus                  0.1814               0.9536
# nllb — wili_2018                    0.1814               0.9789
# glotlid — commonlid                 0.1817               0.9534
# glotlid — flores_plus               0.1817               0.9489
# glotlid — wili_2018                 0.1817               0.9638
# conlid — commonlid                  0.1836               0.9021
# conlid — flores_plus                0.1836               0.9203
# conlid — wili_2018                  0.1836               0.9369
#
#                        Macro F1 (all 11)
# nllb — commonlid                  0.7443
# nllb — flores_plus                0.7430
# nllb — wili_2018                  0.7614
# glotlid — commonlid               0.7429
# glotlid — flores_plus             0.7397
# glotlid — wili_2018               0.7505
# conlid — commonlid                0.7061
# conlid — flores_plus              0.7194
# conlid — wili_2018                0.7314
# target_only
#                        Sinhala (Sinhala)  Pali (Sinhala)  Sanskrit (Sinhala)  \
# nllb — commonlid                  0.9682          0.9601              0.9929
# nllb — flores_plus                0.9969          0.9965              0.9951
# nllb — wili_2018                  0.9969          0.9964              0.9902
# glotlid — commonlid               0.9755          0.9862              0.9921
# glotlid — flores_plus             0.9956          0.9957              0.9943
# glotlid — wili_2018               0.9956          0.9957              0.9895
# conlid — commonlid                0.9656          0.9746              0.9497
# conlid — flores_plus              0.9656          0.9754              0.9519
# conlid — wili_2018                0.9656          0.9754              0.9471
#
#                        Sanskrit (Devanagari)  English   Tamil   Hindi  \
# nllb — commonlid                      0.9329   0.9026  0.9875  0.9574
# nllb — flores_plus                    0.9905   1.0000  1.0000  0.9926
# nllb — wili_2018                      0.9969   0.9448  0.9939  0.9894
# glotlid — commonlid                   0.9645   0.9284  0.9818  0.9618
# glotlid — flores_plus                 0.9955   1.0000  1.0000  0.9931
# glotlid — wili_2018                   0.9975   0.9372  0.9949  0.9107
# conlid — commonlid                    0.9624   0.8505  0.9818  0.9447
# conlid — flores_plus                  0.9985   0.9960  0.9995  0.9970
# conlid — wili_2018                    0.9985   0.9439  0.9944  0.9904
#
#                        Bengali  Modern Standard Arabic  French  German  \
# nllb — commonlid        0.9868                  0.9925  0.9164  0.9414
# nllb — flores_plus      1.0000                  0.6667  0.9995  0.9995
# nllb — wili_2018        0.9429                  0.9980  0.9899  0.9899
# glotlid — commonlid     0.9808                  0.9458  0.9255  0.9213
# glotlid — flores_plus   0.9995                  0.5949  1.0000  1.0000
# glotlid — wili_2018     0.9451                  0.9550  0.9859  0.9738
# conlid — commonlid      0.9623                  0.7167  0.8975  0.8959
# conlid — flores_plus    1.0000                  0.3688  1.0000  0.9970
# conlid — wili_2018      0.9435                  0.6662  0.9808  0.9707
#
#                        Macro F1 (target 3)  Macro F1 (replay 8)  \
# nllb — commonlid                    0.9737               0.9522
# nllb — flores_plus                  0.9962               0.9561
# nllb — wili_2018                    0.9945               0.9807
# glotlid — commonlid                 0.9846               0.9512
# glotlid — flores_plus               0.9952               0.9479
# glotlid — wili_2018                 0.9936               0.9625
# conlid — commonlid                  0.9633               0.9015
# conlid — flores_plus                0.9643               0.9196
# conlid — wili_2018                  0.9627               0.9360
#
#                        Macro F1 (all 11)
# nllb — commonlid                  0.9581
# nllb — flores_plus                0.9670
# nllb — wili_2018                  0.9845
# glotlid — commonlid               0.9603
# glotlid — flores_plus             0.9608
# glotlid — wili_2018               0.9710
# conlid — commonlid                0.9183
# conlid — flores_plus              0.9318
# conlid — wili_2018                0.9433
# replay
#                        Sinhala (Sinhala)  Pali (Sinhala)  Sanskrit (Sinhala)  \
# nllb — commonlid                  0.9852          0.9909              0.9925
# nllb — flores_plus                0.9852          0.9964              0.9947
# nllb — wili_2018                  0.9852          0.9964              0.9899
# glotlid — commonlid               0.9826          0.9939              0.9913
# glotlid — flores_plus             0.9826          0.9939              0.9936
# glotlid — wili_2018               0.9826          0.9939              0.9887
# conlid — commonlid                0.9616          0.9725              0.9386
# conlid — flores_plus              0.9616          0.9726              0.9409
# conlid — wili_2018                0.9616          0.9726              0.9361
#
#                        Sanskrit (Devanagari)  English   Tamil   Hindi  \
# nllb — commonlid                      0.9309   0.9478  0.9875  0.9605
# nllb — flores_plus                    1.0000   0.9661  1.0000  0.9995
# nllb — wili_2018                      0.9980   0.9064  0.9944  0.9889
# glotlid — commonlid                   0.9481   0.9595  0.9878  0.9712
# glotlid — flores_plus                 1.0000   0.9897  1.0000  0.9980
# glotlid — wili_2018                   0.9985   0.9221  0.9949  0.9853
# conlid — commonlid                    0.9609   0.8878  0.9818  0.9491
# conlid — flores_plus                  0.9985   0.9990  0.9995  0.9970
# conlid — wili_2018                    0.9990   0.9377  0.9944  0.9904
#
#                        Bengali  Modern Standard Arabic  French  German  \
# nllb — commonlid        0.9857                  0.9928  0.9377  0.9504
# nllb — flores_plus      1.0000                  0.6667  1.0000  1.0000
# nllb — wili_2018        0.9424                  0.9980  0.9880  0.9904
# glotlid — commonlid     0.9824                  0.9907  0.9355  0.9132
# glotlid — flores_plus   0.9995                  0.6638  0.9995  1.0000
# glotlid — wili_2018     0.9446                  0.9960  0.9870  0.9759
# conlid — commonlid      0.9640                  0.9833  0.9031  0.8984
# conlid — flores_plus    1.0000                  0.6607  1.0000  0.9975
# conlid — wili_2018      0.9435                  0.9935  0.9834  0.9712
#
#                        Macro F1 (target 3)  Macro F1 (replay 8)  \
# nllb — commonlid                    0.9895               0.9617
# nllb — flores_plus                  0.9921               0.9540
# nllb — wili_2018                    0.9905               0.9758
# glotlid — commonlid                 0.9893               0.9610
# glotlid — flores_plus               0.9900               0.9563
# glotlid — wili_2018                 0.9884               0.9755
# conlid — commonlid                  0.9576               0.9411
# conlid — flores_plus                0.9583               0.9565
# conlid — wili_2018                  0.9568               0.9766
#
#                        Macro F1 (all 11)
# nllb — commonlid                  0.9693
# nllb — flores_plus                0.9644
# nllb — wili_2018                  0.9798
# glotlid — commonlid               0.9687
# glotlid — flores_plus             0.9655
# glotlid — wili_2018               0.9790
# conlid — commonlid                0.9456
# conlid — flores_plus              0.9570
# conlid — wili_2018                0.9712
# Saved CSV and LaTeX tables to: d:\Projects\ML Projects\LangID - DSE project\data_pipeline\new_method\results\main_seed42\tables

# %% [markdown]
# ## Inspect the older-language average
# A drop after target-only training is evidence of forgetting on this test set. Improvement with replay is evidence of mitigation. It may be partial, absent, or different across languages.

# %%
import pandas as pd
column = 'Macro F1 (replay 8)'
summary = pd.DataFrame({phase: table[column] for phase,table in tables.items()})
summary['forgetting'] = summary.zero_shot-summary.target_only
summary['recovery'] = summary.replay-summary.target_only
summary['residual_drop'] = summary.zero_shot-summary.replay
display(summary.round(4))
# Out:
#                        zero_shot  target_only  replay  forgetting  recovery  \
# nllb — commonlid          0.9554       0.9522  0.9617      0.0032    0.0095
# nllb — flores_plus        0.9536       0.9561  0.9540     -0.0025   -0.0021
# nllb — wili_2018          0.9789       0.9807  0.9758     -0.0018   -0.0049
# glotlid — commonlid       0.9534       0.9512  0.9610      0.0022    0.0098
# glotlid — flores_plus     0.9489       0.9479  0.9563      0.0011    0.0084
# glotlid — wili_2018       0.9638       0.9625  0.9755      0.0013    0.0130
# conlid — commonlid        0.9021       0.9015  0.9411      0.0006    0.0396
# conlid — flores_plus      0.9203       0.9196  0.9565      0.0007    0.0369
# conlid — wili_2018        0.9369       0.9360  0.9766      0.0008    0.0406
#
#                        residual_drop
# nllb — commonlid             -0.0063
# nllb — flores_plus           -0.0004
# nllb — wili_2018              0.0031
# glotlid — commonlid          -0.0077
# glotlid — flores_plus        -0.0074
# glotlid — wili_2018          -0.0117
# conlid — commonlid           -0.0390
# conlid — flores_plus         -0.0363
# conlid — wili_2018           -0.0398

# %% [markdown]
# ## Record the setup in the paper
# Use `METHOD_AND_CITATIONS.md` and `references.bib`. Report whether replay was independent or sequential, checkpoint revisions, data counts, optimizer, learning rate, example budget, replay fraction, and seed. For stronger evidence, repeat with several seeds and report variability. Do not rename an unobserved decline “catastrophic forgetting”.
